# %%
import random

lang_list = ["PYTHON", "JAVA", "RUST"]

# %%
# b 누르면 코드창이 하나씩 늘어남 라이크 커맨드+엠
lang = random.sample(lang_list,1)

# %%
print("SELECTED LANGUAGE:", lang)
# Out:
# SELECTED LANGUAGE: ['PYTHON']

# %%
def random_language():
    import random
    lang_list = ["PYTHON", "JAVA", "RUST"]
    return random.sample(lang_list,1)
